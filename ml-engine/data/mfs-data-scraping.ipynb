# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf
import time
import os

# Yahoo Mutual Fund URLs (with pagination if needed)
category_urls = {
    "MF Gainers": "https://finance.yahoo.com/markets/mutualfunds/gainers",
    "MF Top Performing": "https://finance.yahoo.com/markets/mutualfunds/top-performing",
    "MF Best Historical": "https://finance.yahoo.com/markets/mutualfunds/best-historical-performance"
}

# Headers with User-Agent and contact
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/122.0.0.0 Safari/537.36"
    ),
    "From": "hrahman@ucdavis.edu"
}

# Create required folders
os.makedirs("./historical-data/mutual-funds", exist_ok=True)
os.makedirs("./market-data", exist_ok=True)

# Scrape up to 100 mutual fund symbols and names
def get_symbols_paginated(url, pages=1):
    results = []
    for page in range(pages):
        full_url = f"{url}?start={page * 100}&count=100"
        response = requests.get(full_url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")
        rows = soup.select("table tbody tr")
        for row in rows:
            cols = row.find_all("td")
            if len(cols) >= 2:
                symbol = cols[0].text.strip()
                name = cols[1].text.strip()
                results.append((symbol, name))
            if len(results) >= 100:
                break
        if len(results) >= 100:
            break
    return results

# Get percent change over a given period
def get_change_pct(ticker, period):
    try:
        hist = yf.Ticker(ticker).history(period=period)
        if hist.empty or len(hist["Close"]) < 2:
            return None
        return round(((hist["Close"].iloc[-1] - hist["Close"].iloc[0]) / hist["Close"].iloc[0]) * 100, 2)
    except:
        return None

# Get all change % for various durations
def get_all_changes(symbol):
    return {
        "Symbol": symbol,
        "1W Change %": get_change_pct(symbol, "5d"),
        "1M Change %": get_change_pct(symbol, "1mo"),
        "3M Change %": get_change_pct(symbol, "3mo"),
        "6M Change %": get_change_pct(symbol, "6mo"),
        "1Y Change %": get_change_pct(symbol, "1y"),
        "5Y Change %": get_change_pct(symbol, "5y")
    }

# Save full historical price series
def save_historical_data(symbol, period="2y"):
    try:
        df = yf.Ticker(symbol).history(period=period, interval="1d")
        if df.empty:
            print(f"-> No data found for {symbol}")
            return
        df.to_csv(f"historical-data/mutual-funds/{symbol}.csv")
        print(f"-> Saved historical data for {symbol}")
    except Exception as e:
        print(f"⚠️ Error saving {symbol}: {e}")

# Master loop
all_data = []

for category, url in category_urls.items():
    print(f"-----Scraping: {category}")
    symbol_name_pairs = get_symbols_paginated(url, pages=1)

    for symbol, name in symbol_name_pairs:
        print(f"→ {symbol} | {name}")
        data = get_all_changes(symbol)
        data["Name"] = name
        data["Category"] = category
        all_data.append(data)

        save_historical_data(symbol)
        time.sleep(1)

df = pd.DataFrame(all_data)
df.to_csv("market-data/mutual-fund-market-data.csv", index=False)
print("-> Saved to market-data/mutual-funds-market-data.csv")
display(df.head())
# Out:
# -----Scraping: MF Gainers
# → FTPAX | First Trust Private Assets Fund
# $FTPAX: possibly delisted; no price data found  (period=5d)
# $FTPAX: possibly delisted; no price data found  (period=1mo)
# $FTPAX: possibly delisted; no price data found  (period=3mo)
# -> Saved historical data for FTPAX
# → GRHIX | Goehring & Rozencwajg Resources Instl
# -> Saved historical data for GRHIX
# → GRHAX | Goehring & Rozencwajg Resources Retail
# -> Saved historical data for GRHAX
# → PMPIX | ProFunds Precious Metals UltraSector Inv
# -> Saved historical data for PMPIX
# → PMPSX | ProFunds Precious Metals UltraSector Svc
# -> Saved historical data for PMPSX
# → 0P00011WC1 | Kieger Fd I Global Real Assets AP1 USD
# -> Saved historical data for 0P00011WC1
# → OCMAX | OCM Gold Atlas
# -> Saved historical data for OCMAX
# → FGPMX | Franklin Gold and Precious Metals R6
# -> Saved historical data for FGPMX
# → OCMGX | OCM Gold Investor
# -> Saved historical data for OCMGX
# → FKRCX | Franklin Gold and Precious Metals A
# -> Saved historical data for FKRCX
# → FRGOX | Franklin Gold and Precious Metals C
# -> Saved historical data for FRGOX
# → FGADX | Franklin Gold and Precious Metals Adv
# -> Saved historical data for FGADX
# → GOLDX | Gabelli Gold AAA
# -> Saved historical data for GOLDX
# → INIIX | VanEck International Investors Gold I
# -> Saved historical data for INIIX
# → GLDAX | Gabelli Gold A
# -> Saved historical data for GLDAX
# → GLDIX | Gabelli Gold I
# -> Saved historical data for GLDIX
# → GLDCX | Gabelli Gold C
# -> Saved historical data for GLDCX
# → IIGCX | VanEck International Investors Gold C
# -> Saved historical data for IIGCX
# → INIYX | VanEck International Investors Gold Y
# -> Saved historical data for INIYX
# → INIVX | VanEck International Investors Gold A
# -> Saved historical data for INIVX
# → UIPMX | Victory Precious Metals and Minerals Fund
# -> Saved historical data for UIPMX
# → UPMMX | Victory Precious Metals and Minerals Fund
# -> Saved historical data for UPMMX
# → USAGX | Victory Precious Metals and Minerals Fund
# -> Saved historical data for USAGX
# → EKWYX | Allspring Precious Metals Fund
# -> Saved historical data for EKWYX
# → EKWAX | Allspring Precious Metals Fund
# -> Saved historical data for EKWAX
# → EKWDX | Allspring Precious Metals Fund
# -> Saved historical data for EKWDX
# → EKWCX | Allspring Precious Metals Fund
# -> Saved historical data for EKWCX
# → UNWPX | U.S. Global Investors World Precious Minerals Fund
# -> Saved historical data for UNWPX
# → USERX | U.S. Global Investors Gold & Precious Metals Fund
# -> Saved historical data for USERX
# → FIJDX | Fidelity Advisor Gold Z
# -> Saved historical data for FIJDX
# → FGDTX | Fidelity Advisor Gold M
# -> Saved historical data for FGDTX
# → IOGYX | Invesco Gold & Special Minerals R5
# -> Saved historical data for IOGYX
# → FGDAX | Fidelity Advisor Gold A
# -> Saved historical data for FGDAX
# → AGGWX | American Century Global Gold R
# -> Saved historical data for AGGWX
# → FSAGX | Fidelity Select Gold
# -> Saved historical data for FSAGX
# → AGYCX | American Century Global Gold C
# -> Saved historical data for AGYCX
# → FGDIX | Fidelity Advisor Gold I
# -> Saved historical data for FGDIX
# → OGMNX | Invesco Gold & Special Minerals R
# -> Saved historical data for OGMNX
# → OPGSX | Invesco Gold & Special Minerals A
# -> Saved historical data for OPGSX
# → FGDCX | Fidelity Advisor Gold C
# -> Saved historical data for FGDCX
# → MIDSX | Midas Discovery
# -> Saved historical data for MIDSX
# → OGMIX | Invesco Gold & Special Minerals R6
# -> Saved historical data for OGMIX
# → OGMYX | Invesco Gold & Special Minerals Y
# -> Saved historical data for OGMYX
# → OGMCX | Invesco Gold & Special Minerals C
# -> Saved historical data for OGMCX
# → AGGNX | American Century Global Gold I
# -> Saved historical data for AGGNX
# → ACGGX | American Century Global Gold A
# -> Saved historical data for ACGGX
# → BGEIX | American Century Global Gold Fund
# -> Saved historical data for BGEIX
# → 0P00017HXX | Kieger Fd I Healthcare Blue Chip A1 USD
# -> Saved historical data for 0P00017HXX
# → BGALX | Baillie Gifford Global Alpha Equities Fund
# -> Saved historical data for BGALX
# → 0P0001SUBL | US Next Technology Fund A",
# -> Saved historical data for 0P0001SUBL
# → 0P0001SUBK | US Next Technology Fund G",
# -> Saved historical data for 0P0001SUBK
# → 0P0001NY2U | Fidelity Advantage Bitcoin ETF - F
# -> Saved historical data for 0P0001NY2U
# → 0P0001NY2W | Fidelity Advantage Bitcoin ETF - B
# -> Saved historical data for 0P0001NY2W
# → 0P0001NY2V | Fidelity Advantage Bitcoin ETF - O
# -> Saved historical data for 0P0001NY2V
# → SGDIX | Sprott Gold Equity Institutional
# -> Saved historical data for SGDIX
# → 0P0001NOFB | Purpose Bitcoin ETF Non-Hedged Cl I
# -> Saved historical data for 0P0001NOFB
# → 0P0001NOFA | Purpose Bitcoin ETF Non-Hedged Cl F
# -> Saved historical data for 0P0001NOFA
# → 0P0001NOF9 | Purpose Bitcoin ETF Non-Hedged Cl A
# -> Saved historical data for 0P0001NOF9
# → SGDLX | Sprott Gold Equity Investor
# -> Saved historical data for SGDLX
# → RYPMX | Rydex Precious Metals Inv
# -> Saved historical data for RYPMX
# → 0P00011WBK | Kieger Fd I Global Commodities AP1 USD
# -> Saved historical data for 0P00011WBK
# → RYMPX | Rydex Precious Metals H
# -> Saved historical data for RYMPX
# → RYMNX | Rydex Precious Metals A
# -> Saved historical data for RYMNX
# → RYZCX | Rydex Precious Metals C
# -> Saved historical data for RYZCX
# $VYSCX: possibly delisted; no price data found  (period=5d)
# → VYSCX | Voya Small Company P3
# $VYSCX: possibly delisted; no price data found  (period=1mo)
# $VYSCX: possibly delisted; no price data found  (period=3mo)
# $VYSCX: possibly delisted; no price data found  (period=6mo)
# $VYSCX: possibly delisted; no price data found  (period=1y)
# -> No data found for VYSCX
# → FEGOX | First Eagle Gold C
# -> Saved historical data for FEGOX
# → FEGIX | First Eagle Gold I
# -> Saved historical data for FEGIX
# → SGGDX | First Eagle Gold A
# -> Saved historical data for SGGDX
# → FEURX | First Eagle Gold R6
# -> Saved historical data for FEURX
# → EPGIX | EuroPac Gold Fund
# -> Saved historical data for EPGIX
# → EPGFX | EuroPac Gold Fund
# -> Saved historical data for EPGFX
# → QGLDX | Gold Bullion Strategy Investor
# -> Saved historical data for QGLDX
# → 0P0000YUAL | Gold Bullion Strategy
# -> Saved historical data for 0P0000YUAL
# → QGLCX | Gold Bullion Strategy Advisor
# -> Saved historical data for QGLCX
# → 0P0001M32M | CI Bitcoin Series F
# -> Saved historical data for 0P0001M32M
# → PSPFX | US Global Investors Global Res
# -> Saved historical data for PSPFX
# → MOWNX | Moerus Worldwide Value N
# -> Saved historical data for MOWNX
# → 0P0001JA5V | Multipartner Tata India Equity D USD Acc
# -> Saved historical data for 0P0001JA5V
# → 0P0001J2MW | Multipartner Tata India Equity C USD Acc
# -> Saved historical data for 0P0001J2MW
# → MOWIX | Moerus Worldwide Value Institutional
# -> Saved historical data for MOWIX
# → 0P0001P1R7 | Multipartner Tata India Equity R USD Acc
# -> Saved historical data for 0P0001P1R7
# → 0P0001J2MV | Multipartner Tata India Equity B USD Acc
# -> Saved historical data for 0P0001J2MV
# → RYVTX | Rydex Inverse NASDAQ-100 2x Strategy A
# -> Saved historical data for RYVTX
# → RYVNX | Rydex Inverse NASDAQ-100 2x Strategy H
# -> Saved historical data for RYVNX
# → RYCDX | Rydex Inverse NASDAQ-100 2x Strategy C
# -> Saved historical data for RYCDX
# → 0P000198KS | Aditya BSL India Qul Adv D$Acc
# -> Saved historical data for 0P000198KS
# → 0P0001OUSR | Aditya BSL India Quality Advant
# -> Saved historical data for 0P0001OUSR
# → 0P0001BRS2 | Aditya BSL India Qul Adv A$Acc
# -> Saved historical data for 0P0001BRS2
# → 0P0001OTZD | Aditya BSL India Qul Adv B$Acc
# -> Saved historical data for 0P0001OTZD
# → 0P0001CLPO | Orbis SICAV Intl Eq Inv
# -> Saved historical data for 0P0001CLPO
# → DTMGX | BNY Mellon Investment Funds IV, Inc. - BNY Mellon Concentrated Growth ETF
# -> Saved historical data for DTMGX
# → MIDNX | Matthews India Instl
# -> Saved historical data for MIDNX
# → DPTAX | BNY Mellon Investment Funds IV, Inc. - BNY Mellon Concentrated Growth ETF
# -> Saved historical data for DPTAX
# → USPSX | ProFunds UltraShort NASDAQ-100 Fund
# -> Saved historical data for USPSX
# → 0P0000RS9F | SIIP India Opportunities A USD Acc
# -> Saved historical data for 0P0000RS9F
# → 0P0000UAHT | SIIP India Opportunities E USD Acc
# -> Saved historical data for 0P0000UAHT
# → 0P0000RS9H | SIIP India Opportunities C USD Acc
# -> Saved historical data for 0P0000RS9H
# → MINDX | Matthews India Investor
# -> Saved historical data for MINDX
# → USPIX | ProFunds UltraShort NASDAQ-100 Fund
# -> Saved historical data for USPIX
# → 0P0001O3TB | --
# -> Saved historical data for 0P0001O3TB
# -----Scraping: MF Top Performing
# → 0P00000C23 | AXA IM Global Small Cap Eq QI B
# -> Saved historical data for 0P00000C23
# → 0P00000C29 | AXA IMAllCntryAPExJpnSmCpEq QI B (US$)
# -> Saved historical data for 0P00000C29
# → 0P00000CAQ | FSSA Indian Subcontinent I USD Acc
# -> Saved historical data for 0P00000CAQ
# → 0P00000HSG | Janus Henderson Glb Rl EstEqInc A2USD
# -> Saved historical data for 0P00000HSG
# → 0P00000HSM | Janus Henderson Glb Rl EstEqInc I1qUSD
# -> Saved historical data for 0P00000HSM
# → 0P00000ICD | Jupiter China Equity Fund L USD Acc
# -> Saved historical data for 0P00000ICD
# → 0P00000IRU | Janus Henderson US Forty I2 USD
# -> Saved historical data for 0P00000IRU
# → 0P00000IS9 | Janus Henderson Balanced B2 USD
# -> Saved historical data for 0P00000IS9
# → 0P00000ISG | Janus Henderson Balanced I2 USD
# -> Saved historical data for 0P00000ISG
# → 0P00000MNK | Vanguard U.S. 500 Stk Idx $ Acc
# -> Saved historical data for 0P00000MNK
# → 0P00000NMO | FTGF CB US Value A USD Dis(A)
# -> Saved historical data for 0P00000NMO
# → 0P00000OB6 | Vanguard US Opportunities Ins USD Acc
# -> Saved historical data for 0P00000OB6
# → 0P00000OB8 | Vanguard US Opportunities Inv USD Acc
# -> Saved historical data for 0P00000OB8
# → 0P00000RLL | Barings ASEAN Frontiers A USD Inc
# -> Saved historical data for 0P00000RLL
# → 0P00000RMH | Principal European Equity A Inc USD
# -> Saved historical data for 0P00000RMH
# → 0P00000RMI | Principal European Equity A Acc USD
# -> Saved historical data for 0P00000RMI
# → 0P00000RMJ | Principal European Equity I Acc USD
# -> Saved historical data for 0P00000RMJ
# → 0P00000RMP | Janus Henderson Balanced A2 USD
# -> Saved historical data for 0P00000RMP
# → 0P00000RMS | Janus Henderson Glb Tech&Inno B2 USD
# -> Saved historical data for 0P00000RMS
# → 0P00000RNC | Vanguard US 500 Stock Index Inv USD Acc
# -> Saved historical data for 0P00000RNC
# → 0P00000RNM | AXA IMAllCntryAPExJpnSmCpEq QI A(US$)
# -> Saved historical data for 0P00000RNM
# → 0P00000RNN | AXA IM Global Equity QI A(US$)
# -> Saved historical data for 0P00000RNN
# → 0P00000RNO | AXA IM Global Small Cap Eq QI A(US$)
# -> Saved historical data for 0P00000RNO
# → 0P00000RPL | Janus Henderson Glb Life Scn A2 USD
# -> Saved historical data for 0P00000RPL
# → 0P00000RPM | Janus Henderson Glb Tech&Inno A2 USD
# -> Saved historical data for 0P00000RPM
# → 0P00000RQA | Vanguard European Stock Idx USD Acc
# -> Saved historical data for 0P00000RQA
# → 0P00000RQB | Vanguard Global Stock Index Inv USD Acc
# -> Saved historical data for 0P00000RQB
# → 0P00000RQD | Vanguard Glb Stk Idx $ Acc
# -> Saved historical data for 0P00000RQD
# → 0P00000T4W | Janus Global Rel Est A USD
# -> Saved historical data for 0P00000T4W
# → 0P00000UJD | PIMCO GIS US Hi Yld Bd Inv USD Acc
# -> Saved historical data for 0P00000UJD
# → 0P00000VK6 | PIMCO GIS Ttl Ret Bd Instl USD Acc
# -> Saved historical data for 0P00000VK6
# → 0P00000WBE | PIMCO GIS Glb Rl Ret Inv USD Acc
# -> Saved historical data for 0P00000WBE
# → 0P00000WBF | PIMCO GIS Glb Rl Ret Instl USD Acc
# -> Saved historical data for 0P00000WBF
# → 0P00000WUL | Value Partners Classic B USD
# -> Saved historical data for 0P00000WUL
# → 0P00000X72 | Emerging World Inst
# -> Saved historical data for 0P00000X72
# → 0P00000XX2 | Principal Glbl High Yield I Acc USD
# -> Saved historical data for 0P00000XX2
# → 0P00000YAP | JPMorgan Pacific Sec (acc) - USD
# -> Saved historical data for 0P00000YAP
# → 0P00000YD6 | Brandes European Value A USD
# -> Saved historical data for 0P00000YD6
# → 0P00000YD9 | Brandes European Value I USD
# -> Saved historical data for 0P00000YD9
# → 0P00000YDC | Brandes Global Value A USD Acc
# -> Saved historical data for 0P00000YDC
# → 0P00000YDF | Brandes Global Value I USD Acc
# -> Saved historical data for 0P00000YDF
# → 0P00000ZE0 | PIMCO GIS Global Real Return Fund H Institutional USD Accumulation
# -> Saved historical data for 0P00000ZE0
# → 0P00000ZE7 | PIMCO GIS US High Yield Bond Fund H Institutional USD Accumulation
# -> Saved historical data for 0P00000ZE7
# → 0P00000ZF0 | PIMCO GIS Total Return Bond Fund H Institutional USD Accumulation
# -> Saved historical data for 0P00000ZF0
# → 0P000010PE | Dimensional European Small Companies Fund USD Accumulation
# -> Saved historical data for 0P000010PE
# → 0P000010PL | Dimensional Pacific Basin Small Companies Fund USD Accumulation
# -> Saved historical data for 0P000010PL
# → 0P000011NM | PIMCO GIS Total Return Bond Fund Institutional USD Income
# -> Saved historical data for 0P000011NM
# → 0P000013EG | Jupiter Merian World Equity Fund B USD Acc
# -> Saved historical data for 0P000013EG
# → 0P000013GL | Jupiter China Equity Fund B USD Acc
# -> Saved historical data for 0P000013GL
# → 0P000014FB | iShares Japan Index Fund (IE) Flexible Acc USD
# -> Saved historical data for 0P000014FB
# → 0P000014FE | iShares Pacific Index Fund (IE) Flexible Acc USD
# -> Saved historical data for 0P000014FE
# → 0P000015HL | Muzinich Enhancedyield Short-Term Fund Hedged USD Accumulation A Units
# -> Saved historical data for 0P000015HL
# → 0P000015K8 | Dimensional U.S. Small Companies Fund USD Accumulation
# -> Saved historical data for 0P000015K8
# → 0P0000187T | Payden Global Emerging Markets Bond Fund USD (Accumulating)
# -> Saved historical data for 0P0000187T
# → 0P0000187W | Payden Global High Yield Bond Fund USD (Accumulating)
# -> Saved historical data for 0P0000187W
# → 0P000018HA | FSSA Greater China Growth Fund Class I (Accumulation) USD
# -> Saved historical data for 0P000018HA
# → 0P00001BHA | JPMorgan Thailand (acc) - USD
# -> Saved historical data for 0P00001BHA
# → 0P00001BIN | JPMorgan Asian Smlr Coms (acc) - USD
# -> Saved historical data for 0P00001BIN
# → 0P00001BJE | FSSA ASEAN All Cap I USD Acc
# -> Saved historical data for 0P00001BJE
# → 0P00001BQ3 | FSSA China Growth II USD Acc
# -> Saved historical data for 0P00001BQ3
# → 0P00001BQK | FSSA Indian Subcontinent II USD Acc
# -> Saved historical data for 0P00001BQK
# → 0P00001DS4 | JPMorgan Evergreen
# -> Saved historical data for 0P00001DS4
# → 0P00001EVJ | PineBridge US Large Cap Research Enhnd Y
# -> Saved historical data for 0P00001EVJ
# → 0P00001SNB | SEI GMF Hi Yld Fxd Inc USD Instl Acc
# -> Saved historical data for 0P00001SNB
# → 0P00001T1G | SEI GMF Global Equity USD Instl Acc
# -> Saved historical data for 0P00001T1G
# → 0P00001T82 | SEI GMF US Fixed Inc USD Instl Acc
# -> Saved historical data for 0P00001T82
# → 0P00001W1W | Janus Balanced A USD
# -> Saved historical data for 0P00001W1W
# → 0P00001W5H | SEI GMF Global Fxd Inc USD Instl Acc
# -> Saved historical data for 0P00001W5H
# → 0P00001WGX | SEI GMF Emerg Markets Eq USD Instl Inc
# -> Saved historical data for 0P00001WGX
# → 0P00001WH0 | SEI GMF Emerg Markets Eq USD Instl Acc
# -> Saved historical data for 0P00001WH0
# → 0P00001WKG | PIMCO GIS Glb Rl Ret Instl USD Inc
# -> Saved historical data for 0P00001WKG
# → 0P00001WLU | SEI GMF Emerg Mkts Dbt USD Instl Acc
# -> Saved historical data for 0P00001WLU
# → 0P00001WMR | SEI GMF UK Equity USD Instl Acc
# -> Saved historical data for 0P00001WMR
# → 0P00001ZJA | SEI GMF Global Equity USD Instl Inc
# -> Saved historical data for 0P00001ZJA
# → 0P00001ZKA | SEI GMF Small Cap Sel USD Instl Acc
# -> Saved historical data for 0P00001ZKA
# → 0P0000202Z | SEI GMF Small Cap Sel USD Instl Inc
# -> Saved historical data for 0P0000202Z
# → 0P000023E0 | GAM Star European Equity Ord USD Acc
# -> Saved historical data for 0P000023E0
# → 0P000023E1 | GAM Star European Equity Ord USD Inc
# -> Saved historical data for 0P000023E1
# → 0P000023OZ | Ninety One Global Strategic Eq A Acc USD
# -> Saved historical data for 0P000023OZ
# → 0P00002448 | SEI GMF Global Fxd Inc H USD Instl Acc
# -> Saved historical data for 0P00002448
# → 0P000024Y2 | Cabei Central American Acc
# -> Saved historical data for 0P000024Y2
# → 0P0000258N | BlackRock ICS USD Liquidity Core Acc
# -> Saved historical data for 0P0000258N
# → 0P000025ZS | New Capital Glbl Val Crdt USD Ord Acc
# -> Saved historical data for 0P000025ZS
# → 0P000026CE | Wellington Global Bond USD S Ac
# -> Saved historical data for 0P000026CE
# → 0P000026CF | Wellington Global Hlthcr Eq USD G Ac
# -> Saved historical data for 0P000026CF
# → 0P000029IH | PineBridge Japan Equity Y
# -> Saved historical data for 0P000029IH
# → 0P00002CGU | Veritas Global Equity Income B USD
# -> Saved historical data for 0P00002CGU
# → 0P00005VON | Pzena Global Focused Value A USD Acc
# -> Saved historical data for 0P00005VON
# → 0P00005XSH | PIMCO GIS Glb Hi Yld Bd Instl USD Acc
# -> Saved historical data for 0P00005XSH
# → 0P00006OKD | iShares North America Idx (IE) Flex Acc$
# -> Saved historical data for 0P00006OKD
# → 0P00007VNS | AXA IM Global EM Eq QI A(USD)
# -> Saved historical data for 0P00007VNS
# → 0P00007VNU | AXA IM Global EM Eq QI B(USD)
# -> Saved historical data for 0P00007VNU
# → 0P00008E99 | FSSA Hong Kong Growth I USD Acc
# -> Saved historical data for 0P00008E99
# → 0P00008MLX | Waverton Global Equity A USD
# -> Saved historical data for 0P00008MLX
# → 0P00008MM1 | Waverton Global Equity B USD
# -> Saved historical data for 0P00008MM1
# → 0P00008SS4 | JPMorgan SAR Asian - A acc - USD
# -> Saved historical data for 0P00008SS4
# → 0P00008T2I | FTGF CB US Value A USD Acc
# -> Saved historical data for 0P00008T2I
# → 0P00008VB6 | JPMorgan SAR Japan - A acc - USD
# -> Saved historical data for 0P00008VB6
# → 0P00008VOQ | Waverton Asia Pacific A USD
# -> Saved historical data for 0P00008VOQ
# → 0P000099K6 | Value Partners Classic A USD
# -> Saved historical data for 0P000099K6
# -----Scraping: MF Best Historical
# → MFLLX | Morgan Stanley Inst Inception R6
# -> Saved historical data for MFLLX
# → MSSGX | Morgan Stanley Inst Inception I
# -> Saved historical data for MSSGX
# → MSSMX | Morgan Stanley Inst Inception A
# -> Saved historical data for MSSMX
# → BPTIX | Baron Partners Institutional
# -> Saved historical data for BPTIX
# → BPTUX | Baron Partners R6
# -> Saved historical data for BPTUX
# → BPTRX | Baron Partners Retail
# -> Saved historical data for BPTRX
# → MSSLX | Morgan Stanley Inst Inception L
# -> Saved historical data for MSSLX
# → ADNIX | American Beacon ARK Transfmt Innov R5
# -> Saved historical data for ADNIX
# → MSCOX | Morgan Stanley Inst Inception C
# -> Saved historical data for MSCOX
# → ADNYX | American Beacon ARK Transfmt Innov Y
# -> Saved historical data for ADNYX
# → ADNPX | American Beacon ARK Transfmt Innov Inv
# -> Saved historical data for ADNPX
# → ADNAX | American Beacon ARK Transfmt Innov A
# -> Saved historical data for ADNAX
# → ADNCX | American Beacon ARK Transfmt Innov C
# -> Saved historical data for ADNCX
# → ZVGIX | Zevenbergen Genea Institutional
# -> Saved historical data for ZVGIX
# → ZVGNX | Zevenbergen Genea Investor
# -> Saved historical data for ZVGNX
# → MMCGX | Morgan Stanley Inst Discovery R6
# -> Saved historical data for MMCGX
# → MPEGX | Morgan Stanley Inst Discovery I
# -> Saved historical data for MPEGX
# → MACGX | Morgan Stanley Institutional Fund Trust Discovery Portfolio
# -> Saved historical data for MACGX
# → MSKLX | Morgan Stanley Inst Discovery L
# -> Saved historical data for MSKLX
# → MSMFX | Morgan Stanley Inst Discovery C
# -> Saved historical data for MSMFX
# → BGGKX | Baillie Gifford U.S. Equity Growth Fund
# -> Saved historical data for BGGKX
# → BGGSX | Baillie Gifford US Equity Growth I
# -> Saved historical data for BGGSX
# → ZVNIX | Advisor Managed Portfolios - Zevenbergen Growth Fund
# -> Saved historical data for ZVNIX
# → ZVNBX | Zevenbergen Growth Investor
# -> Saved historical data for ZVNBX
# → JAMFX | Jacob Internet Fund
# -> Saved historical data for JAMFX
# → BFGUX | Baron Focused Growth Fund
# -> Saved historical data for BFGUX
# → BFGIX | Baron Focused Growth Fund
# -> Saved historical data for BFGIX
# → BFGFX | Baron Focused Growth Fund
# -> Saved historical data for BFGFX
# → SCATX | Virtus Zevenbergen Innovative Gr Stk I
# -> Saved historical data for SCATX
# → SAGAX | Virtus Zevenbergen Innovative Gr Stk A
# -> Saved historical data for SAGAX
# → MCRTX | Morgan Stanley Insight Fund
# -> Saved historical data for MCRTX
# → CPODX | Morgan Stanley Insight I
# -> Saved historical data for CPODX
# → CPOAX | Morgan Stanley Insight A
# -> Saved historical data for CPOAX
# → MGRPX | Morgan Stanley Inst Growth R6
# -> Saved historical data for MGRPX
# → MGHRX | Morgan Stanley Inst Growth IR
# -> Saved historical data for MGHRX
# → MSEQX | Morgan Stanley Inst Growth I
# -> Saved historical data for MSEQX
# → MSEGX | Morgan Stanley Inst Growth A
# -> Saved historical data for MSEGX
# → CPOCX | Morgan Stanley Insight L
# -> Saved historical data for CPOCX
# → MSCMX | Morgan Stanley Insight C
# -> Saved historical data for MSCMX
# → MSHLX | Morgan Stanley Inst Growth L
# -> Saved historical data for MSHLX
# → NEXTX | Shelton Sustainable Equity Investor
# -> Saved historical data for NEXTX
# → MSGUX | Morgan Stanley Inst Growth C
# -> Saved historical data for MSGUX
# → 0P00003AB2 | Transamerica Capital Growth I2
# -> Saved historical data for 0P00003AB2
# → TFOIX | Transamerica Capital Growth I
# -> Saved historical data for TFOIX
# → IALAX | Transamerica Capital Growth A
# -> Saved historical data for IALAX
# → MSJSX | Morgan Stanley Global Endurance R6
# -> Saved historical data for MSJSX
# → MSJIX | Morgan Stanley Global Endurance I
# -> Saved historical data for MSJIX
# → ILLLX | Transamerica Capital Growth C
# -> Saved historical data for ILLLX
# → MSJAX | Morgan Stanley Global Endurance A
# -> Saved historical data for MSJAX
# → UPUPX | Upright Growth Fund
# -> Saved historical data for UPUPX
# → MSJCX | Morgan Stanley Global Endurance C
# -> Saved historical data for MSJCX
# → BGLTX | Baillie Gifford Long Term Global Growth Fund
# -> Saved historical data for BGLTX
# → BGLKX | Baillie Gifford Long Term Global Growth Fund
# -> Saved historical data for BGLKX
# → BSGLX | Baillie Gifford Long Term Global Gr I
# -> Saved historical data for BSGLX
# → 0P00018JE1 | Baillie Gifford WW L/T Glb Gr B USD Acc
# -> Saved historical data for 0P00018JE1
# → RMQHX | Rydex Monthly Rbl NASDAQ-100 2x Strt H
# -> Saved historical data for RMQHX
# → RMQAX | Rydex Monthly Rbl NASDAQ-100 2x Strt A
# -> Saved historical data for RMQAX
# → RMQCX | Rydex Monthly Rbl NASDAQ-100 2x Strt C
# -> Saved historical data for RMQCX
# → SGNFX | Sparrow Growth No-Load
# -> Saved historical data for SGNFX
# → SGFFX | Sparrow Growth A
# -> Saved historical data for SGFFX
# → BTLKX | Baillie Gifford Intl Concntr Gr EqsK
# -> Saved historical data for BTLKX
# → BTLSX | Baillie Gifford Intl Concntr Gr EqsInstl
# -> Saved historical data for BTLSX
# → TEFQX | Firsthand Technology Opportunities
# -> Saved historical data for TEFQX
# → SGFCX | Sparrow Growth C
# -> Saved historical data for SGFCX
# → MIGIX | Morgan Stanley Inst Global Insgt I
# -> Saved historical data for MIGIX
# → MIGPX | Morgan Stanley Inst Global Insgt A
# -> Saved historical data for MIGPX
# → MIGLX | Morgan Stanley Inst Global Insgt L
# -> Saved historical data for MIGLX
# → MSPTX | Morgan Stanley Inst Global Insgt C
# -> Saved historical data for MSPTX
# → BFOCX | Berkshire Focus Fund
# -> Saved historical data for BFOCX
# → 0P00016GSS | Sanlam Anchor Global Equity A USD Acc
# -> Saved historical data for 0P00016GSS
# → BIOUX | Baron Opportunity Fund
# -> Saved historical data for BIOUX
# → BIOIX | Baron Opportunity Fund
# -> Saved historical data for BIOIX
# → 0P0001D7PT | Baillie Gifford Worldwide Positive Change Fund
# -> Saved historical data for 0P0001D7PT
# → 0P0001A4HN | E Fund (HK) Grtr Chn Leaders I USD Acc
# -> Saved historical data for 0P0001A4HN
# → BIOPX | Baron Opportunity Fund
# -> Saved historical data for BIOPX
# → VBPIX | Vanguard Baillie GiffordGlbPstvImpStkInv
# -> Saved historical data for VBPIX
# → RYVYX | Rydex NASDAQ-100 2x Strategy H
# -> Saved historical data for RYVYX
# → RYVLX | Rydex NASDAQ-100 2x Strategy A
# -> Saved historical data for RYVLX
# → 0P0001ALVM | E Fund (HK) Grtr Chn Leaders A USD Inc
# -> Saved historical data for 0P0001ALVM
# → 0P0001A4HM | E Fund (HK) Grtr Chn Leaders A USD Acc
# -> Saved historical data for 0P0001A4HM
# → 0P00017WW8 | UPAMC Global Innovative Tech USD
# -> Saved historical data for 0P00017WW8
# → MITEX | Matthews Asia Innovators Institutional
# -> Saved historical data for MITEX
# → RYCCX | Rydex NASDAQ-100 2x Strategy C
# -> Saved historical data for RYCCX
# → LFGVX | Lord Abbett Focused Growth R6
# -> Saved historical data for LFGVX
# → MATFX | Matthews Asia Innovators Fund
# -> Saved historical data for MATFX
# → UOPIX | ProFunds UltraNASDAQ-100 Fund
# -> Saved historical data for UOPIX
# → BGSIX | BlackRock Technology Opportunities Fund
# -> Saved historical data for BGSIX
# → LFGOX | Lord Abbett Focused Growth F3
# -> Saved historical data for LFGOX
# → LFGFX | Lord Abbett Focused Growth F
# -> Saved historical data for LFGFX
# → LFGTX | Lord Abbett Focused Growth R5
# -> Saved historical data for LFGTX
# → LFGIX | Lord Abbett Focused Growth I
# -> Saved historical data for LFGIX
# → GAAEX | Guinness Atkinson Alternative Energy
# -> Saved historical data for GAAEX
# → BSTSX | BlackRock Technology Opportunities Svc
# -> Saved historical data for BSTSX
# → BGSAX | BlackRock Technology Opportunities Fund
# -> Saved historical data for BGSAX
# → LFGAX | Lord Abbett Focused Growth A
# -> Saved historical data for LFGAX
# → LFGSX | Lord Abbett Focused Growth R4
# -> Saved historical data for LFGSX
# → 0P00019LM6 | Nikko AM Asian Small Mid Eq USD Acc
# -> Saved historical data for 0P00019LM6
# → BGSRX | BlackRock Technology Opportunities Fund
# -> Saved historical data for BGSRX
# → LFGQX | Lord Abbett Focused Growth R3
# -> Saved historical data for LFGQX
# → DMCRX | Driehaus Micro Cap Growth Fund
# -> Saved historical data for DMCRX
# -> Saved to market-data/mutual-funds-market-data.csv
#   Symbol  1W Change %  1M Change %  3M Change %  6M Change %  1Y Change %  \
# 0  FTPAX          NaN          NaN          NaN          NaN          NaN
# 1  GRHIX         5.37        10.56        11.44         2.86         0.12
# 2  GRHAX         5.29        10.47        11.26         2.63        -0.21
# 3  PMPIX         9.44        -0.77        30.33        50.64        57.56
# 4  PMPSX         9.43        -0.85        30.02        49.92        56.04
#
#    5Y Change %                                      Name    Category
# 0        11.21           First Trust Private Assets Fund  MF Gainers
# 1       221.84     Goehring & Rozencwajg Resources Instl  MF Gainers
# 2       216.34    Goehring & Rozencwajg Resources Retail  MF Gainers
# 3        25.52  ProFunds Precious Metals UltraSector Inv  MF Gainers
# 4        19.45  ProFunds Precious Metals UltraSector Svc  MF Gainers
